# %% [markdown]
# # 05 Full Invariance Information Loss
#
# Finite witness for [`../05_full_invariance_information_loss.md`](../05_full_invariance_information_loss.md). This Notebook is not a proof or empirical model result.

# %%
import numpy as np
# C is constant, P=Y is balanced. Complete invariance sees only C.
y = np.array([0, 1])
full_invariant_log_risk = -np.mean(np.log(np.array([0.5, 0.5])))
high_support_log_risk = 0.0
conditional_information = np.log(2.0)
assert np.isclose(full_invariant_log_risk - high_support_log_risk, conditional_information)
print("THEORY_DEMO_PASS::05_full_invariance_information_loss")
